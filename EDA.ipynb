# %%
from data_utils import Dset, get_loader 
from transformers import BertTokenizer

from utils import * 
from settings import *

# %%
train_df = load_pkl(os.path.join(DATA_DIR, 'train.pkl'))
valid_df = load_pkl(os.path.join(DATA_DIR, 'valid.pkl'))
test_df = load_pkl(os.path.join(DATA_DIR, 'test.pkl'))

# %%
class args:
    max_len = 256 
    batch_size = 256
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
train_loader = get_loader(args, train_df)
valid_loader = get_loader(args, valid_df)
test_loader = get_loader(args, test_df)
# Out:
# ...
# Loading images...:   0%|          | 0/22991 [00:00<?, ?it/s]

# %%
train_batch = next(iter(train_loader))

# %%
sample_img = train_batch['image'][10]

# %%
plot_imshow(sample_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
